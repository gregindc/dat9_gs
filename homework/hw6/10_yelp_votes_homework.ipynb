# %% [markdown]
# # Linear regression homework with Yelp votes

# %% [markdown]
# ## Introduction
#
# This assignment uses a small subset of the data from Kaggle's [Yelp Business Rating Prediction](https://www.kaggle.com/c/yelp-recsys-2013) competition.
#
# **Description of the data:**
#
# - `yelp.json` is the original format of the file. `yelp.csv` contains the same data, in a more convenient format. Both of the files are in this repo, so there is no need to download the data from the Kaggle website.
# - Each observation in this dataset is a review of a particular business by a particular user.
# - The "stars" column is the number of stars (1 through 5) assigned by the reviewer to the business. (Higher stars is better.) In other words, it is the rating of the business by the person who wrote the review.
# - The "cool" column is the number of "cool" votes this review received from other Yelp users. All reviews start with 0 "cool" votes, and there is no limit to how many "cool" votes a review can receive. In other words, it is a rating of the review itself, not a rating of the business.
# - The "useful" and "funny" columns are similar to the "cool" column.

# %% [markdown]
# ## Task 1
#
# Read `yelp.csv` into a DataFrame.

# %%
# access yelp.csv using a relative path
import pandas as pd

yelp_data = pd.read_csv("https://raw.githubusercontent.com/ga-students/DAT-DC-9/master/data/yelp.csv?token=AOHBy-_yzVkBZJFxpyctn_KozjMGn3STks5WP_oewA%3D%3D")
# Out:
#                  business_id        date               review_id  stars  \
# 0     9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1     ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2     6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3     _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4     6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
# 5     -yxfBYGB6SEqszmxJxd97A  2007-12-13  m2CKSsepBCoRYWxiRUsxAg      4
# 6     zp713qNhx8d9KCJJnrw1xA  2010-02-12  riFQ3vxNpP4rWLk_CSri2A      5
# 7     hW0Ne_HTHEAgGF1rAdmR-g  2012-07-12  JL7GXJ9u4YMx7Rzs05NfiQ      4
# 8     wNUea3IXZWD63bbOQaOH-g  2012-08-17  XtnfnYmnJYi71yIuGsXIUA      4
# 9     nMHhuYan8e3cONo3PornJA  2010-08-11  jJAIXA46pU1swYyRCdfXtQ      5
# 10    AsSCv0q_BWqIe3mX2JqsOQ  2010-06-16  E11jzpKz9Kw5K7fuARWfRw      5
# 11    e9nN4XxjdHj4qtKCOPq_vg  2011-10-21  3rPt0LxF7rgmEUrznoH22w      5
# ...

# %% [markdown]
# ## Task 1 (Bonus)
#
# Ignore the `yelp.csv` file, and construct this DataFrame yourself from `yelp.json`. This involves reading the data into Python, decoding the JSON, converting it to a DataFrame, and adding individual columns for each of the vote types.

# %%
# read the data from yelp.json into a list of rows
import requests
import json
import csv
from pandas.io.json import json_normalize

r = requests.get('https://raw.githubusercontent.com/ga-students/DAT-DC-9/master/data/yelp.json?token=AOHBy-xKpMCKLTKuJC_8doFm5FeyOnM0ks5WP_sjwA%3D%3D')
yelp_list = r.text.split("\n")
yelp_list

# each row is decoded into a dictionary using using json.loads()
yd = []
for line in yelp_list:
    #print type(line)
    if(line != ""):
        yd.append(json.loads(line))
    
len(yd)
# Out:
# 10000

# %%
# show the first review
print yd[0]
# Out:
# {u'votes': {u'funny': 0, u'useful': 5, u'cool': 2}, u'user_id': u'rLtl8ZkDX5vH5nAx9C3q5Q', u'review_id': u'fWKvX83p0-ka4JS3dc6E5A', u'text': u'My wife took me here on my birthday for breakfast and it was excellent.  The weather was perfect which made sitting outside overlooking their grounds an absolute pleasure.  Our waitress was excellent and our food arrived quickly on the semi-busy Saturday morning.  It looked like the place fills up pretty quickly so the earlier you get here the better.\n\nDo yourself a favor and get their Bloody Mary.  It was phenomenal and simply the best I\'ve ever had.  I\'m pretty sure they only use ingredients from their garden and blend them fresh when you order it.  It was amazing.\n\nWhile EVERYTHING on the menu looks excellent, I had the white truffle scrambled eggs vegetable skillet and it was tasty and delicious.  It came with 2 pieces of their griddled bread with was amazing and it absolutely made the meal complete.  It was the best "toast" I\'ve ev
# ...

# %%
# convert the list of dictionaries to a DataFrame
json_df = pd.DataFrame(yd)
json_df
# Out:
#                  business_id        date               review_id  stars  \
# 0     9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1     ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2     6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3     _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4     6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
# 5     -yxfBYGB6SEqszmxJxd97A  2007-12-13  m2CKSsepBCoRYWxiRUsxAg      4
# 6     zp713qNhx8d9KCJJnrw1xA  2010-02-12  riFQ3vxNpP4rWLk_CSri2A      5
# 7     hW0Ne_HTHEAgGF1rAdmR-g  2012-07-12  JL7GXJ9u4YMx7Rzs05NfiQ      4
# 8     wNUea3IXZWD63bbOQaOH-g  2012-08-17  XtnfnYmnJYi71yIuGsXIUA      4
# 9     nMHhuYan8e3cONo3PornJA  2010-08-11  jJAIXA46pU1swYyRCdfXtQ      5
# 10    AsSCv0q_BWqIe3mX2JqsOQ  2010-06-16  E11jzpKz9Kw5K7fuARWfRw      5
# 11    e9nN4XxjdHj4qtKCOPq_vg  2011-10-21  3rPt0LxF7rgmEUrznoH22w      5
# ...

# %%
# add DataFrame columns for cool, useful, and funny
json_df['cool'] = 0
json_df['funny'] = 0
json_df['useful'] = 0
def feat(dfr):
    dfr['cool'] = dfr.votes['cool']
    dfr['funny'] = dfr.votes['funny']
    dfr['useful'] = dfr.votes['useful']
    return dfr
json_df = json_df.apply(feat, axis=1)
json_df.head()
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id                                    votes  cool  \
# 0  rLtl8ZkDX5vH5nAx9C3q5Q  {u'funny': 0, u'useful': 5, u'cool': 2}     2
# ...

# %%
# drop the votes column
json_df.drop('votes', axis=1, inplace=True)
json_df
# Out:
#                  business_id        date               review_id  stars  \
# 0     9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1     ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2     6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3     _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4     6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
# 5     -yxfBYGB6SEqszmxJxd97A  2007-12-13  m2CKSsepBCoRYWxiRUsxAg      4
# 6     zp713qNhx8d9KCJJnrw1xA  2010-02-12  riFQ3vxNpP4rWLk_CSri2A      5
# 7     hW0Ne_HTHEAgGF1rAdmR-g  2012-07-12  JL7GXJ9u4YMx7Rzs05NfiQ      4
# 8     wNUea3IXZWD63bbOQaOH-g  2012-08-17  XtnfnYmnJYi71yIuGsXIUA      4
# 9     nMHhuYan8e3cONo3PornJA  2010-08-11  jJAIXA46pU1swYyRCdfXtQ      5
# 10    AsSCv0q_BWqIe3mX2JqsOQ  2010-06-16  E11jzpKz9Kw5K7fuARWfRw      5
# 11    e9nN4XxjdHj4qtKCOPq_vg  2011-10-21  3rPt0LxF7rgmEUrznoH22w      5
# ...

# %% [markdown]
# ## Task 2
#
# Explore the relationship between each of the vote types (cool/useful/funny) and the number of stars.

# %%
# treat stars as a categorical variable and look for differences between groups
json_df.groupby('stars').mean()
# Out:
#            cool     funny    useful
# stars
# 1      0.576769  1.056075  1.604806
# 2      0.719525  0.875944  1.563107
# 3      0.788501  0.694730  1.306639
# 4      0.954623  0.670448  1.395916
# 5      0.944261  0.608631  1.381780

# %%
json_df.groupby('stars').agg(['count','mean'])
# Out:
#        cool           funny           useful
#       count      mean count      mean  count      mean
# stars
# 1       749  0.576769   749  1.056075    749  1.604806
# 2       927  0.719525   927  0.875944    927  1.563107
# 3      1461  0.788501  1461  0.694730   1461  1.306639
# 4      3526  0.954623  3526  0.670448   3526  1.395916
# 5      3337  0.944261  3337  0.608631   3337  1.381780

# %%
json_df.stars.value_counts()
# Out:
# 4    3526
# 5    3337
# 3    1461
# 2     927
# 1     749
# dtype: int64

# %%
# correlation matrix
# %matplotlib inline
json_df.corr()
pd.scatter_matrix(json_df[['cool', 'funny', 'useful']], figsize=(10, 8))
sns.pairplot(json_df, x_vars=feature_cols, y_vars='stars', kind='reg')

# %% [markdown]
# ## Task 3
#
# Define cool/useful/funny as the features, and stars as the response.

# %%
feature_cols = ['cool', 'useful', 'funny']
X = json_df[feature_cols]
y=json_df.stars

# %% [markdown]
# ## Task 4
#
# Fit a linear regression model and interpret the coefficients. Do the coefficients make intuitive sense to you? Explore the Yelp website to see if you detect similar trends.

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X,y)
print linreg.intercept_
print linreg.coef_
# comments: it makes sense in that the average star rating in general is around 3.8 so no comments at all would still
# reflect around that minimum star rating. Then, positive correlation for cool and negative for funny and useful seems
# to correspond with the correlation matrix above
# Out:
# 3.83989479278
# [ 0.27435947 -0.14745239 -0.13567449]

# %% [markdown]
# ## Task 5
#
# Evaluate the model by splitting it into training and testing sets and computing the RMSE. Does the RMSE make intuitive sense to you?

# %%
from sklearn import metrics
import numpy as np
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
linreg.fit(X_train,y_train)
pred = linreg.predict(X_test)
true = y_test
np.sqrt(metrics.mean_squared_error(true, pred))
# Out:
# 1.180192896464537

# %%
# define a function that accepts a list of features and returns testing RMSE
def rmse(feature_cols):
    X = json_df[feature_cols]
    y = json_df.stars
    linreg = LinearRegression()
    linreg.fit(X, y)
    y_pred = linreg.predict(X)
    return np.sqrt(metrics.mean_squared_error(y, y_pred))

# %%
# calculate RMSE with all three features
rmse(['cool','useful','funny'])
# Out:
# 1.211734821417741

# %% [markdown]
# ## Task 6
#
# Try removing some of the features and see if the RMSE improves.

# %%
print rmse(['cool'])
print rmse(['useful'])
print rmse(['funny'])

print rmse(['cool','useful'])
print rmse(['cool','funny'])
print rmse(['useful','funny'])
# Out:
# 1.21289706659
# 1.21424072273
# 1.21229091531
# 1.19878841159
# 1.19774127503
# 1.21173482142

# %% [markdown]
# ## Task 7 (Bonus)
#
# Think of some new features you could create from the existing data that might be predictive of the response. Figure out how to create those features in Pandas, add them to your model, and see if the RMSE improves.

# %%
# new feature: review length (number of characters)
json_df['text_len'] = json_df['text'].str.len()
rmse(['text_len'])
# Out:
# 1.2065631770872205

# %%
# new features: whether or not the review contains 'love' or 'hate'
json_df['love'] = json_df['text'].str.contains('love')
json_df['hate'] = json_df['text'].str.contains('hate')

# %%
# add new features to the model and calculate RMSE
print rmse(['love'])
print rmse(['hate','funny','useful'])
# Out:
# 1.20172817119
# 1.21070955351

# %% [markdown]
# ## Task 8 (Bonus)
#
# Compare your best RMSE on the testing set with the RMSE for the "null model", which is the model that ignores all features and simply predicts the mean response value in the testing set.

# %%
# split the data (outside of the function)

# %%
# create a NumPy array with the same shape as y_test

# %%
# fill the array with the mean of y_test

# %%
# calculate null RMSE

# %% [markdown]
# ## Task 9 (Bonus)
#
# Instead of treating this as a regression problem, treat it as a classification problem and see what testing accuracy you can achieve with KNN.

# %%
# import and instantiate KNN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=20)
feature_cols = ['love', 'hate', 'text_len']
X = json_df[feature_cols]
y=json_df.stars
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.3408

# %%
# classification models will automatically treat the response value (1/2/3/4/5) as unordered categories

# %% [markdown]
# ## Task 10 (Bonus)
#
# Figure out how to use linear regression for classification, and compare its classification accuracy with KNN's accuracy.

# %%
# use linear regression to make continuous predictions

# %%
# round its predictions to the nearest integer

# %%
# calculate classification accuracy of the rounded predictions
